# %%
import pandas as pd
data = pd.read_csv('C:/Users/devanshi/SHL-Assessment-Recommendation-System_Devanshi-Singh/data/processed/shl_product_catalog_cleaned.csv')
data
# Out:
#                                                 Name  \
# 0                           account manager solution
# 1            administrative professional  short form
# 2                            agency manager solution
# 3              apprentice  80 job focused assessment
# 4               apprentice 80 job focused assessment
# 5          bank administrative assistant  short form
# 6                 bank collections agent  short form
# 7             bank operations supervisor  short form
# 8       bilingual spanish reservation agent solution
# 9   bookkeeping accounting auditing clerk short form
# 10                        branch manager  short form
# 11                                  cashier solution
# 12                  global skills development report
# 13                                  net framework 45
# 14                                       net mvc new
# 15                                      net mvvm new
# 16                                       net wcf new
# ...

# %%
# Combine relevant fields into a single text column for embedding
data['text_for_embedding'] = data['Name']

# %%
print(data[['text_for_embedding']].head())
# Out:
#                         text_for_embedding
# 0                 account manager solution
# 1  administrative professional  short form
# 2                  agency manager solution
# 3    apprentice  80 job focused assessment
# 4     apprentice 80 job focused assessment

# %%
data.to_csv('shl_product_catalog_ready_for_embedding.csv', index=False)
print("Saved dataset with 'text_for_embedding' column.")
# Out:
# Saved dataset with 'text_for_embedding' column.
